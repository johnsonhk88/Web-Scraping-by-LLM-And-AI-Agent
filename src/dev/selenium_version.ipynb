# %%
# install libraries

# %%
# !pip3 install selenium
# !pip3 install webdriver-manager

# %% [markdown]
# ## import libraries

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from transformers import pipeline

# %%
url = "https://www.timeout.com.hk/hong-kong/hk/%E5%A5%BD%E5%8E%BB%E8%99%95/%E9%A6%99%E6%B8%AF%E7%87%88%E8%AC%8E%E9%A1%8C%E7%9B%AE%E7%B2%BE%E9%81%B8-%E9%A6%99%E6%B8%AF%E5%9C%B0%E5%90%8D%E7%8C%9C%E5%AD%97%E7%AD%94%E6%A1%88"

# %%
def scrapeDynamicWebsite(url, tag="p"):
    # Initialize the Chrome webdriver
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')  # Run in headless mode (no GUI)
    driver = webdriver.Chrome(options=options)
    
    # Open the URL
    driver.get(url)
    time.sleep(3) # Wait for the page to load

    # get the page source
    raw = driver.page_source
    # get tag elements
    data = driver.find_elements(By.TAG_NAME, tag)
    elements= []
    for item in data:
        elements.append(item.text.strip())
    # close the driver
    # driver.close()
    driver.quit()

    return raw, elements

# %%
raw, tagData = scrapeDynamicWebsite(url, tag="p")

# %%
len(tagData), tagData
# Out:
# (64,
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '與親朋好友共度佳節！',
#   '每逢傳統佳節日元宵節和中秋節，香港各區增添古色古香而浪漫的氣氛。康文署會舉行中秋綵燈會，一家大小、情侶在夜晚漫步賞燈，欣賞傳統手藝。以下整合了我們聽過好玩的中秋燈謎，看看你能猜中幾題！繼續看更多中秋節活動推介2024。',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '乘人不備（猜一字）- 乖',
#   '餐廳24小時營業（猜一天文現象）- 日全蝕（食）',
#   "鑽石跌落廁所（猜一香港地方）- 東涌（Don't 沖）",
#   '米奇老鼠與唐老鴨（猜一字）- 糖',
#   '招搖過市（猜一天文名詞）- 太陽（揚）',
#   '兩姐妹，一樣長，酸甜苦辣，她先嘗（猜一物件）- 筷子',
#   '和尚擔遮（猜一成語）- 無法無天（無頭髮）',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '令你翹首盼望的電郵',
#   '輸入電子郵箱地址，即表示閣下同意 使用條款 細則及 私隱政策內容',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '將我們加到你的收件箱',
#   '輸入電子郵箱地址，即表示閣下同意 使用條款 細則及 私隱政策內容',
#   '',
#   '',
#   '關於我們',
#   '聯繫我們',
#   'Time Out產品',
#   'Time Out 雜誌'])

# %%
print(raw)
# Out:
# <html lang="zh-HK"><head><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1"><link rel="icon" href="/static/images/favicon.ico" sizes="16x16" type="image/x-icon"><link rel="icon" href="/static/images/favicon-32.png" sizes="32x32" type="image/png"><link rel="icon" href="/static/images/favicon-48.png" sizes="48x48" type="image/png"><link rel="apple-touch-icon" href="/static/images/favicon-180.png" type="image/png"><title>香港中秋燈謎題目答案精選</title><meta name="description" content="康文署每年舉行元宵及中秋綵燈會，一家大小、情侶在夜晚漫步賞燈，欣賞傳統手藝。以下整合了我們聽過好玩的中秋燈謎題目和答案，看看以下香港燈謎你能猜中幾題！"><link rel="canonical" href="https://www.timeout.com.hk/hong-kong/hk/好去處/香港燈謎題目精選-香港地名猜字答案"><meta name="robots" content="max-image-preview:large"><script src="https://securepubads.g.doubleclick.net/pagead/managed/js/gpt/m202412090101/pubads_impl_page_level_ads.js"></script><script type="text/javascript" async="" src="https://content.zeotap.com/sdk/idp.min.js"></script><script src="https:
# ...
